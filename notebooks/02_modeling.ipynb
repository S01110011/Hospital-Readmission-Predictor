# %% [markdown]
# # 02 - Modeling
#
# Treinamento e comparacao de modelos.

# %%
from src.models.train import train_models

package = train_models()
package['model_name']

# %%
import json
from pathlib import Path

json.loads(Path('artifacts/metrics.json').read_text())
