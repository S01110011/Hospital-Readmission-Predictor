# %% [markdown]
# # 01 - EDA
#
# Exploracao inicial do dataset sintetico de readmissao hospitalar.

# %%
from src.data.load_data import load_dataset

df = load_dataset()
df.head()

# %%
df.describe(include='all').T

# %%
df['readmitted_30_days'].value_counts(normalize=True).rename('rate')
