# %% [markdown]
# # 03 - Explainability
#
# Ponto de partida para analise de importancia e SHAP.

# %%
import joblib

package = joblib.load('artifacts/model.joblib')
package.keys()

# %% [markdown]
# Em producao, gere explicacoes com SHAP no conjunto de validacao e revise com especialistas clinicos. Explicabilidade estatistica nao deve ser interpretada automaticamente como causalidade.
